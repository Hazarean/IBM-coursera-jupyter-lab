# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystems are summarized.

# %% [markdown]
# **Objectives**:
# - List popular languages used for Data Science.
# - List common languages used by Data Scientists.
# - List some tools used by Data Scientists in a table.
# - Provide some examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1) Python
# 2) R
# 3) Scala
# 4) Julia
# 5) Matlab

# %% [markdown]
# Some of the commonly used libaries in Data Science include:
# 1) sk-learn
# 2) pandas
# 3) numpy
# 4) seaborn
# 5) matplotlib
# 6) tensorflow
# 7) plotly

# %% [markdown]
# | Data Science Tools |
# |:------------------:|
# |  Jupyter Notebook  |
# |    Apache Spark    |
# |       KNIME        |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Joseph Parker
